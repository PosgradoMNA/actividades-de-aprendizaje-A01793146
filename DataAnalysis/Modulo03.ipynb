# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01793146/blob/main/DataAnalysis/Modulo03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('assignment01 for GitJobish03 and edited in git, and 18')
# Out:
# assignment01 for GitJobish03 and edited in git, and 18

# %% [markdown]
# # Ciencia y Analítica de Datos (Gpo10)
# # Profesora: Dra. María de la Paz Rico Fernández
# # Alumnno: Alejandro Jesús Vázquez Navarro
# # Matrícula: A01793146
# # Módulo 3 (Data Analysis with Python, IBM)

# %%
# Notes and exercises for Module 3
# These are the libraries that I will use

import pandas as pd
import numpy as np

# Now, download the dataset:
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

df = pd.read_csv(path)

# Examine the first 5 rows

df.head(5)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# I will matplotlib in order to have some dataviz

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Let's visualize the datatypes

print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# Question #1:
# What is the data type of the column "peak-rpm"?

# %%
print(df["peak-rpm"].dtype)
# Out:
# float64

# %%
# I can calculate the corr for all the quantitive variables within the dataframe
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Question #2:
# Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.
#
# Hint: if you would like to select those columns, use the following syntax: df[['bore','stroke','compression-ratio','horsepower']]

# %%
dfCorr = df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
dfCorr
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
# I will plot the correlation between engine size and price

sns.regplot(x = "engine-size", y ="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53614.880208146904)

# %%
# We can observe a correlation between these two variables, because as the engine size goes up, so the price does.
# Let's see the value of this correlation

df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
# We can deepen into the correlation between highway-mpg and price
df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
# and plot this corr
sns.regplot(x ="highway-mpg", y="price", data=df) 

# We can observe that we have a negative and strong correlation between these two variables

# %%
# Let's examine another correlation
df[['peak-rpm','price']].corr()

# It's very weak, let's plot it
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x ="peak-rpm", y="price", data=df)

# %% [markdown]
# Question 3 a):
# Find the correlation between x="stroke" and y="price".
#
# Hint: if you would like to select those columns, use the following syntax:
# df[["stroke","price"]].

# %%
df[['stroke','price']].corr()

# There is a low corr. Let's plot it
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# Question 3 b):
# Given the correlation results between "price" and "stroke", do you expect a linear relationship?
#
# Verify your results using the function "regplot()".

# %%
sns.regplot(x ="stroke", y="price", data=df)

# %%
# Let's review some categorical variables
# Categorical variable describe a characteristics.
# We can plot it some of them. Let's see body-stile and price

sns.boxplot(x="body-style", y="price", data=df)

# %%
# This graph is pretty helpful to understand the distribution of the price in each one of the groups
# We can graph another relation between price and drive-wheels

sns.boxplot(x="drive-wheels", y="price", data=df)

# %% [markdown]
# # Descriptive Statistical Analysis

# %%
# We can use describe() method to show the following statistics: mean, count, std, min, IQA, max

df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
# We can filter just for one kind of data
# In this case, just the object data types are described it.

df.describe(include=["object"])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
# I can count how many units of each characteristics I have.
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
# I can pass this result to a dataframe
myDF = df["drive-wheels"].value_counts().to_frame

myDF = df['drive-wheels'].value_counts().to_frame()
myDF.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
myDF
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
# Grouping
# With grouping I can group data by differente categories.
# For example

df['drive-wheels'].unique()

# I want the mean for this variable
df_my_group = df[['drive-wheels','body-style','price']]
df_my_group = df_my_group.groupby(['drive-wheels'],as_index=False).mean()
df_my_group
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
# This is another approach:

# grouping results
df_another_approach = df[['drive-wheels','body-style','price']]
grouped_test1 = df_another_approach.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1

grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
# We can see that we have some NaNs
# Let's remove this
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Question 4:
# Use the "groupby" function to find the average "price" of each car based on "body-style".

# %%
df_question4 = df[['body-style','price']]
grouped_test_bodystyle = df_question4.groupby(['body-style'],as_index= False).mean()
grouped_test_bodystyle
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
# I want to see this in a plot

#use the grouped results
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
# Now let's examine correlation and causation

# %%
# I can review all correlation coeficientes with

df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
# Let's examine the p-value
# The p value is just the probability that the correlation between 2 variables is statistically significant. A good significance level is 0.05, this means that we're 95% confident that the correlation is significant.
# We'll use scipy for this matter

from scipy import stats

# %%
# And calculate the pearson correlation coefficient and p value for wheel-base and price
pearson, pvalue = stats.pearsonr(df['wheel-base'], df['price'])
print("¨Pearson Coeff is ", pearson, " and the p value is =", pvalue)
# Out:
# ¨Pearson Coeff is  0.584641822265508  and the p value is = 8.076488270733218e-20

# %%
# We got a p < 0.001 this means that the correlation between wheel-base and price is statistically significant however the linear relationship is not that strong (0.58)

# %%
# Let's see another correlation
# length vs price

pearson, pvalue = stats.pearsonr(df['length'], df['price'])
print("¨Pearson Coeff is ", pearson, " and the p value is =", pvalue)  

# p value < 0.001 (this is significant although the correlation is moderately strong (0.69))
# Out:
# ¨Pearson Coeff is  0.6906283804483638  and the p value is = 8.016477466159556e-30

# %%
# Another one:
# engine-size vs price
pearson, pvalue = stats.pearsonr(df['engine-size'], df['price'])
print("¨Pearson Coeff is ", pearson, " and the p value is =", pvalue)  

# p value < 0.001 (this is significant and has a very strong correlation (0.87))
# Out:
# ¨Pearson Coeff is  0.8723351674455185  and the p value is = 9.265491622198389e-64

# %%
# Let's run some anova tests

anova_group=df_another_approach[['drive-wheels', 'price']].groupby(['drive-wheels'])
anova_group.head(2)

df_another_approach

# Let's obtain the values of the method group:
anova_group.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
# And finally run the one way test:

fscore_val, p_value = stats.f_oneway(anova_group.get_group('fwd')['price'], anova_group.get_group('rwd')['price'], anova_group.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", fscore_val, ", P =", p_value)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
# If F score is greater than one then we have a strong correlation and a P near to 0 means a certain statistical significance.
# Let's examine this group separately

fscore_val, p_value = stats.f_oneway(anova_group.get_group('fwd')['price'], anova_group.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", fscore_val, ", P =", p_value )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
# Let's examine the other group:
fscore_val, p_value = stats.f_oneway(anova_group.get_group('4wd')['price'], anova_group.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", fscore_val, ", P =", p_value)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
fscore_val, p_value = stats.f_oneway(anova_group.get_group('4wd')['price'], anova_group.get_group('fwd')['price'])  
 
print("ANOVA results: F=", fscore_val, ", P =", p_value)  

# This last one has not statistically significance because we have a p > 0.001
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %% [markdown]
# Evidencia del Módulo 3
#
# ![image.png](data:image/png;base64,...)
